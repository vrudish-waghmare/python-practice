# %% [markdown]
# # Classes and Objects
# Object-Oriented Programming (OOP) is a programming that uses "objects" to design applications and computer programs. OOP allows for modeling real-world scenarios using classes and objects.

# %%
# A class is a blue print for creating objects, Atributes, methods
class Car:
    pass 

audi = Car()
bmw = Car()
print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
print(audi)
print(bmw)
# Out:
# <__main__.Car object at 0x0000019FF9EDBB60>
# <__main__.Car object at 0x0000019FF9EC0CD0>

# %%
audi.windows = 4
print(audi.windows)
# Out:
# 4

# %%
tata = Car()
tata.doors = 4
print(tata.windows)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 tata = Car()
#       2 tata.doors = 4
# ----> 3 print(tata.windows)
#
# AttributeError: 'Car' object has no attribute 'windows'

# %%
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
class Dog:
    ## constructor
    def __init__(self, name, age):
        self.name = name 
        self.age = age 
    
# create objects
dog1 = Dog("Tommy", 8)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# <__main__.Dog object at 0x0000019FFAEADFD0>
# Tommy
# 8

# %%
dog2 = Dog("Lucy", 4)
print(dog2.name)
print(dog2.age)
# Out:
# Lucy
# 4

# %%
# define a class with instance methods
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age 
    
    def bark(self):
        print(f"{self.name} says woof")

dog1 = Dog("Tommy",8)
dog1.bark()
dog2 = Dog("Lucy", 4)
dog2.bark()
# Out:
# Tommy says woof
# Lucy says woof

# %%
# Real World Example: 
# Modeling a Bank Account
class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner 
        self.balance = balance 
    
    def deposit(self, amount):
        self.balance += amount 
        print(f"{amount} is deposited. New balance is {self.balance}")
    
    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds!")
        else:
            self.balance -= amount 
            print(f"{amount} is withdrawn. New balance is {self.balance}")
    
    def get_balance(self):
        return self.balance 


# create an account
account = BankAccount("Vrudish", 5000)
print(account.balance)
# Out:
# 5000

# %%
# Call instance methods
account.deposit(1000)
# Out:
# 1000 is deposited. New balance is 6000

# %%
account.withdraw(500)
# Out:
# 500 is withdrawn. New balance is 5500

# %%
print(account.get_balance())
# Out:
# 5500
